# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 100)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
import sys
import datetime
import re

import warnings; warnings.filterwarnings('ignore')

sys.path.append('..')
from src.data.process_data import process_data
from config import CFG
CFG = CFG()

# %%
date = datetime.datetime(2023, 2, 10).strftime('%Y-%m-%d')
current_dir = os.path.abspath(os.path.dirname(os.getcwd()))
data_dir = os.path.join(current_dir, "data_files")
raw_data = os.path.join(data_dir, "raw")
processed_data = os.path.join(data_dir, "processed")

CFG.RAW_DATA_PATH = raw_data
CFG.PROCESSED_DATA_PATH = processed_data
CFG.DATE = date

# %%
df = pd.read_csv(os.path.join(CFG.PROCESSED_DATA_PATH, f"df-processed-{CFG.DATE}.csv"))

# %%
# df = df.replace({None: np.nan}, regex=False)

opioid = df[(df['category'] == 'Opioid') | (df['expected drug'].isin([
    'Fentanyl and Methamphetamine', 'Down and Methamphetamine', 'Heroin and Methamphetamine', 'Heroin and Cocaine'
])) ].index
df['expected opioid'] = df.index.isin(opioid).astype(int)
df
# Out:
#       visit date       city                   site          expected drug  \
# 0     2023-01-31  Penticton              Fairhaven  Down (Unknown Opioid)
# 1     2023-01-31  Vancouver  Get Your Drugs Tested                Unknown
# 2     2023-01-31  Vancouver  Get Your Drugs Tested             Alprazolam
# 3     2023-01-31    Nanaimo                   CMHA  Down (Unknown Opioid)
# 4     2023-01-31  Cranbrook     ANKORS (Cranbrook)        Methamphetamine
# ...          ...        ...                    ...                    ...
# 59995 2018-12-03  Vancouver                 Insite                   MDMA
# 59996 2018-12-03  Vancouver                 Insite               Fentanyl
# 59997 2018-12-03  Vancouver                Getaway                Unknown
# 59998 2018-12-03  Vancouver                Getaway               Fentanyl
# 59999 2018-12-03     Nelson        ANKORS (Nelson)               Fentanyl
#
#           category         colour   texture  fentanyl strip  benzo strip  \
# 0           Opioid         Purple     Chunk               1           -1
# 1          Unknown  Brown (light)     Chunk               1           -1
# 2       Depressant  Green (light)     Chunk              -1            1
# 3           Opioid           Pink    Powder               1            1
# 4        Stimulant     Colourless   Crystal              -1            0
# ...            ...            ...       ...             ...          ...
# 59995  Psychedelic          Black  Granules               0            0
# 59996       Opioid         Purple  Granules               1            0
# 59997      Unknown     Colourless   Crystal              -1            0
# 59998       Opioid          Green    Pebble               1            0
# 59999       Opioid           Grey    Pebble               1            0
#
#       ftir component 0            ftir component 1 ftir component 2  \
# 0             Fentanyl                  Erythritol         Caffeine
# 1      Uncertain match                    Fentanyl             None
# 2        Flualprazolam  Microcrystalline cellulose             None
# 3             Fentanyl                    Mannitol         Caffeine
# 4      Methamphetamine                        None             None
# ...                ...                         ...              ...
# 59995  Uncertain match                  Phenacetin             None
# 59996         Caffeine                    Inositol       Heroin hcl
# 59997  Methamphetamine                        None             None
# 59998         Fentanyl                    Caffeine         Mannitol
# 59999         Caffeine                    Fentanyl             None
#
#       ftir component 3 ftir component 4 ftir component 5  expected opioid
# 0                 None             None             None                1
# 1                 None             None             None                0
# 2                 None             None             None                0
# 3           Bromazolam             None             None                1
# 4                 None             None             None                0
# ...                ...              ...              ...              ...
# 59995             None             None             None                0
# 59996         Fentanyl             None             None                1
# 59997             None             None             None                0
# 59998         Mannitol         Caffeine         Fentanyl                1
# 59999             None             None             None                1
#
# [60000 rows x 16 columns]

# %% [markdown]
# # Matching FTIR and Fentanyl Strip
# - Now lets investigate if the results from the FTIR and fentanyl strip match

# %%
def opioid_present(col):
    """
    This function uses a list of regex strings to find if any opioids are present in a given column (ftir components).
    """
    opioid_list = ['(despropionyl\s)?(para-fluoro)?(carf|f)entan(i|y)l( base)?', 
                   'heroin.*', 
                   '(hydro|oxy).*one', 
                   'opium', 
                   'w-1(8|9)', 
                   '6-mam', 
                   '.*tazene', 
                   '(code|morph)ine',
                   '(furanyl\s)?uf-17']
    if col is None:
        return 0
    for item in opioid_list:
        return 1 if re.search(item, col, re.IGNORECASE) else 0

# %%
ftirs = [x for x in df.columns.tolist() if x.startswith('ftir')]
for col in ftirs:
    df[col] = df[col].astype(str)

opioids = df.loc[:, [f'ftir component {i}' for i in range(6)]].applymap(lambda x: opioid_present(x))
opioids = opioids.apply(sum, axis=1).astype(bool).astype(int)
df['contains_opioids'] = opioids

incorrect_strip = df[(df['contains_opioids'] == 1) & (df['fentanyl strip'] == -1)]
incorrect_ftir = df[(df['contains_opioids'] == -1) & (df['fentanyl strip'] == 1)]
len(incorrect_strip), len(incorrect_ftir)
# Out:
# (31, 0)

# %% [markdown]
# - this is very surprising!
# - the strips use something called an immunoassay, which uses antibodies to detect the fentanyl.
# - antibodies are extremely specific and sensitive, more so than the FTIR spec
# - lets look a little closer

# %%
incorrect_strip.loc[:, [f'ftir component {i}' for i in range(6)]]
# Out:
#       ftir component 0        ftir component 1        ftir component 2  \
# 2086        Erythritol                Fentanyl                    None
# 2463          Caffeine                Fentanyl              Erythritol
# 6794          Caffeine                Fentanyl                    None
# 7934          Caffeine              Erythritol                Fentanyl
# 17815         Mannitol                Fentanyl                Caffeine
# 22214         Fentanyl         Uncertain match                    None
# 27122         Fentanyl                    None                    None
# 33625         Caffeine                Fentanyl  Uncertain carbohydrate
# 38128   Propionanilide         Uncertain match                Fentanyl
# 47286         Caffeine                Mannitol                Fentanyl
# 50152         Caffeine                Fentanyl                    None
# 50878  Uncertain match                Fentanyl                    None
# 53044         Caffeine              Erythritol                Fentanyl
# 55038         Caffeine  Uncertain carbohydrate                Fentanyl
# 56966         Caffeine                Fentanyl              Erythritol
# 57076         Fentanyl                 Lactose                Caffeine
# 57203         Fentanyl     Polyethylene glycol                Caffeine
# 57222       Erythritol     Polyethylene glycol              Erythritol
# 57238         Fentanyl     Polyethylene glycol              Erythritol
# 57365         Caffeine              Erythritol               Vitamin c
# 57417         Caffeine                Fentanyl                 Xylitol
# 57448       Heroin hcl                Fentanyl                Mannitol
# 57974         Caffeine                Fentanyl                    None
# 58146         Caffeine         Methamphetamine                Fentanyl
# 58213         Mannitol                Caffeine                Fentanyl
# 58413         Fentanyl                    None                    None
# 58815         Fentanyl                Caffeine                    None
# 59187         Fentanyl                Inositol                Caffeine
# 59431         Fentanyl                 Lactose                    None
# 59838         Caffeine                Mannitol                Fentanyl
# 59961         Mannitol                Caffeine                Fentanyl
#
#       ftir component 3 ftir component 4 ftir component 5
# 2086              None             None             None
# 2463              None             None             None
# 6794              None             None             None
# 7934              None             None             None
# 17815             None             None             None
# 22214             None             None             None
# 27122             None             None             None
# 33625             None             None             None
# 38128             None             None             None
# 47286             None             None             None
# 50152             None             None             None
# 50878             None             None             None
# 53044             None             None             None
# 55038             None             None             None
# 56966             None             None             None
# 57076         Mannitol             None             None
# 57203       Heroin hcl             None             None
# 57222         Fentanyl         Caffeine         Caffeine
# 57238         Caffeine             None             None
# 57365         Fentanyl             None             None
# 57417             None             None             None
# 57448         Caffeine             None             None
# 57974             None             None             None
# 58146         Mannitol             None             None
# 58213             None             None             None
# 58413             None             None             None
# 58815             None             None             None
# 59187             None             None             None
# 59431             None             None             None
# 59838             None             None             None
# 59961             None             None             None

# %% [markdown]
# - They are all the generic fentanyl, not even the more potent carfent.
# - Possibly human error, lets see how spread out the sites are

# %%
ratio = len(df) / len(incorrect_strip)

test = incorrect_strip['site'].value_counts()

baseline = df['site'].value_counts() / ratio
baseline = baseline[baseline.index.isin(test.index)]

test / baseline
# Out:
# ASK Wellness (433 Tranquille)    4.19
# Abbotsford Hub                  18.43
# Get Your Drugs Tested            0.50
# Insite                           4.72
# Molson OPS                       3.22
# Outreach Urban Health            8.20
# POUNDS                           5.94
# Name: site, dtype: float64

# %% [markdown]
# - We will only use Insite and Get Your Drugs Tested since the sample size is a bit more significant.
# - So, there is almost 5 times more samples from Insite with incorrect FTIR than there should be, according to the baseline
# - We should also take a look at the dates to see if they are spread out or clumped (maybe new employee or batch of strips)

# %%
def format_site(row) -> list[str]:
    if row['site'] == 'ASK Wellness (433 Tranquille)':
        return ['background-color: #C3ACD0; color: white'] * len(row)
    elif row['site'] == 'Get Your Drugs Tested':
        return ['background-color: #7286D3; color: white'] * len(row)
    elif row['site'] == 'Insite':
        return ['background-color: #645CBB; color: white'] * len(row)
    else:
        return ['background-color: #8EA7E9; color: white'] * len(row)

def format_df(styler):
    styler.set_caption('Days Between Incorrect Strip Results per Site')
    styler.format(formatter={
        'log_per_site_diff': '{:.2f}',
        'per_site_diff': '{:.0f}',
        'visit date': '{:%Y-%m-%d}'
        })
    styler.apply(format_site, axis=1)  #
    styler.background_gradient(cmap='Reds', axis=0, subset=['log_per_site_diff'])
    return styler

# %%
incorrect_strip['per_site_diff'] = incorrect_strip.groupby(['site'])['visit date'].diff(-1)
incorrect_strip['per_site_diff'] = incorrect_strip['per_site_diff'].dt.days

incorrect_strip_df = incorrect_strip[['visit date', 'site', 'per_site_diff']].dropna()
incorrect_strip_df['log_per_site_diff'] = (incorrect_strip_df['per_site_diff'] + 1).apply(np.log)
incorrect_strip_df.style.pipe(format_df)
# Out:
# <style type="text/css">
# #T_e9589_row0_col0, #T_e9589_row0_col1, #T_e9589_row0_col2 {
#   background-color: #C3ACD0;
#   color: white;
# }
# #T_e9589_row0_col3 {
#   background-color: #C3ACD0;
#   color: white;
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e9589_row1_col0, #T_e9589_row1_col1, #T_e9589_row1_col2, #T_e9589_row2_col0, #T_e9589_row2_col1, #T_e9589_row2_col2, #T_e9589_row3_col0, #T_e9589_row3_col1, #T_e9589_row3_col2, #T_e9589_row4_col0, #T_e9589_row4_col1, #T_e9589_row4_col2, #T_e9589_row5_col0, #T_e9589_row5_col1, #T_e9589_row5_col2, #T_e9589_row6_col0, #T_e9589_row6_col1, #T_e9589_row6_col2, #T_e9589_row7_col0, #T_e9589_row7_col1, #T_e9589_row7_col2, #T_e9589_row8_col0, #T_e9589_row8_col1, #T_e9589_row8_col2, #T_e9589_row9_col0, #T_e9589_row9_col1, #T_e9589_row9_col2 {
#   background-color: #7286D3;
#   color: white;
# }
# #T_e9589_row1_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #db2824;
#   color: #f1f1f1;
# }
# #T_e9589_row2_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_e9589_row3_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_e9589_row4_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #da2723;
#   color: #f1f1f1;
# }
# #T_e9589_row5_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_e9589_row6_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #c7171c;
#   color: #f1f1f1;
# }
# #T_e9589_row7_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_e9589_row8_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_e9589_row9_col3 {
#   background-color: #7286D3;
#   color: white;
#   background-color: #e12d26;
#   color: #f1f1f1;
# }
# #T_e9589_row10_col0, #T_e9589_row10_col1, #T_e9589_row10_col2, #T_e9589_row12_col0, #T_e9589_row12_col1, #T_e9589_row12_col2, #T_e9589_row13_col0, #T_e9589_row13_col1, #T_e9589_row13_col2, #T_e9589_row14_col0, #T_e9589_row14_col1, #T_e9589_row14_col2, #T_e9589_row16_col0, #T_e9589_row16_col1, #T_e9589_row16_col2, #T_e9589_row17_col0, #T_e9589_row17_col1, #T_e9589_row17_col2, #T_e9589_row18_col0, #T_e9589_row18_col1, #T_e9589_row18_col2, #T_e9589_row19_col0, #T_e9589_row19_col1, #T_e9589_row19_col2, #T_e9589_row20_col0, #T_e9589_row20_col1, #T_e9589_row20_col2, #T_e9589_row21_col0, #T_e9589_row21_col1, #T_e9589_row21_col2, #T_e9589_row22_col0, #T_e9589_row22_col1, #T_e9589_row22_col2, #T_e9589_row23_col0, #T_e9589_row23_col1, #T_e9589_row23_col2 {
#   background-color: #645CBB;
#   color: white;
# }
# #T_e9589_row10_col3, #T_e9589_row21_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fc9070;
#   color: #000000;
# }
# #T_e9589_row11_col0, #T_e9589_row11_col1, #T_e9589_row11_col2, #T_e9589_row15_col0, #T_e9589_row15_col1, #T_e9589_row15_col2 {
#   background-color: #8EA7E9;
#   color: white;
# }
# #T_e9589_row11_col3 {
#   background-color: #8EA7E9;
#   color: white;
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_e9589_row12_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e9589_row13_col3, #T_e9589_row18_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_e9589_row14_col3, #T_e9589_row19_col3, #T_e9589_row23_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fcad90;
#   color: #000000;
# }
# #T_e9589_row15_col3 {
#   background-color: #8EA7E9;
#   color: white;
#   background-color: #ef3c2c;
#   color: #f1f1f1;
# }
# #T_e9589_row16_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fb6b4b;
#   color: #f1f1f1;
# }
# #T_e9589_row17_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fc9b7c;
#   color: #000000;
# }
# #T_e9589_row20_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fa6547;
#   color: #f1f1f1;
# }
# #T_e9589_row22_col3 {
#   background-color: #645CBB;
#   color: white;
#   background-color: #fc7f5f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e9589">
#   <caption>Days Between Incorrect Strip Results per Site</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9589_level0_col0" class="col_heading level0 col0" >visit date</th>
#       <th id="T_e9589_level0_col1" class="col_heading level0 col1" >site</th>
#       <th id="T_e9589_level0_col2" class="col_heading level0 col2" >per_site_diff</th>
#       <th id="T_e9589_level0_col3" class="col_heading level0 col3" >log_per_site_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9589_level0_row0" class="row_heading level0 row0" >2463</th>
#       <td id="T_e9589_row0_col0" class="data row0 col0" >2023-01-25</td>
#       <td id="T_e9589_row0_col1" class="data row0 col1" >ASK Wellness (433 Tranquille)</td>
#       <td id="T_e9589_row0_col2" class="data row0 col2" >1197</td>
#       <td id="T_e9589_row0_col3" class="data row0 col3" >7.09</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row1" class="row_heading level0 row1" >6794</th>
#       <td id="T_e9589_row1_col0" class="data row1 col0" >2022-10-26</td>
#       <td id="T_e9589_row1_col1" class="data row1 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row1_col2" class="data row1 col2" >135</td>
#       <td id="T_e9589_row1_col3" class="data row1 col3" >4.91</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row2" class="row_heading level0 row2" >17815</th>
#       <td id="T_e9589_row2_col0" class="data row2 col0" >2022-06-13</td>
#       <td id="T_e9589_row2_col1" class="data row2 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row2_col2" class="data row2 col2" >66</td>
#       <td id="T_e9589_row2_col3" class="data row2 col3" >4.20</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row3" class="row_heading level0 row3" >22214</th>
#       <td id="T_e9589_row3_col0" class="data row3 col0" >2022-04-08</td>
#       <td id="T_e9589_row3_col1" class="data row3 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row3_col2" class="data row3 col2" >82</td>
#       <td id="T_e9589_row3_col3" class="data row3 col3" >4.42</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row4" class="row_heading level0 row4" >27122</th>
#       <td id="T_e9589_row4_col0" class="data row4 col0" >2022-01-16</td>
#       <td id="T_e9589_row4_col1" class="data row4 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row4_col2" class="data row4 col2" >138</td>
#       <td id="T_e9589_row4_col3" class="data row4 col3" >4.93</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row5" class="row_heading level0 row5" >33625</th>
#       <td id="T_e9589_row5_col0" class="data row5 col0" >2021-08-31</td>
#       <td id="T_e9589_row5_col1" class="data row5 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row5_col2" class="data row5 col2" >89</td>
#       <td id="T_e9589_row5_col3" class="data row5 col3" >4.50</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row6" class="row_heading level0 row6" >38128</th>
#       <td id="T_e9589_row6_col0" class="data row6 col0" >2021-06-03</td>
#       <td id="T_e9589_row6_col1" class="data row6 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row6_col2" class="data row6 col2" >222</td>
#       <td id="T_e9589_row6_col3" class="data row6 col3" >5.41</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row7" class="row_heading level0 row7" >47286</th>
#       <td id="T_e9589_row7_col0" class="data row7 col0" >2020-10-24</td>
#       <td id="T_e9589_row7_col1" class="data row7 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row7_col2" class="data row7 col2" >91</td>
#       <td id="T_e9589_row7_col3" class="data row7 col3" >4.52</td>
#     </tr>
#     <tr>
#       <th id="T_e9589_level0_row8" class="row_heading level0 row8" >50152</th>
#       <td id="T_e9589_row8_col0" class="data row8 col0" >2020-07-25</td>
#       <td id="T_e9589_row8_col1" class="data row8 col1" >Get Your Drugs Tested</td>
#       <td id="T_e9589_row

# %% [markdown]
# - It does look like there was human error due to the clumping nature
# - Further, there is almost a weekly pattern, which could be when that employee was working and the ceasing of it could be them quitting
# - Get Your Drugs Tested results are so spaced out and erratic if it was human error, it is more of a one-off
