# %%
# %%load_ext autoreload
# %autoreload 2
# Out:
# UsageError: Cell magic `%%load_ext` not found (But line magic `%load_ext` exists, did you mean that instead?).

# %%
import pandas as pd
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import os
import sys
import datetime

import warnings; warnings.filterwarnings('ignore')

sys.path.append('..')
from config import CFG
CFG = CFG()

# %%
pd.read_csv(f'../data_files/processed/df-2023-02-10.csv')
# Out:
#        visit date       city                   site          expected drug  \
# 0      2023-01-31  Penticton              Fairhaven  Down (Unknown Opioid)
# 1      2023-01-31  Vancouver  Get Your Drugs Tested                Unknown
# 2      2023-01-31  Vancouver  Get Your Drugs Tested             Alprazolam
# 3      2023-01-31    Nanaimo                   CMHA  Down (Unknown Opioid)
# 4      2023-01-31  Cranbrook     ANKORS (Cranbrook)        Methamphetamine
# ...           ...        ...                    ...                    ...
# 59995  2018-12-03  Vancouver                 Insite                   MDMA
# 59996  2018-12-03  Vancouver                 Insite               Fentanyl
# 59997  2018-12-03  Vancouver                Getaway                Unknown
# 59998  2018-12-03  Vancouver                Getaway               Fentanyl
# 59999  2018-12-03     Nelson        ANKORS (Nelson)               Fentanyl
#
#           category         colour   texture  fentanyl strip  benzo strip  \
# 0           Opioid         Purple     Chunk               1           -1
# 1          Unknown  Brown (light)     Chunk               1           -1
# 2       Depressant  Green (light)     Chunk              -1            1
# 3           Opioid           Pink    Powder               1            1
# 4        Stimulant     Colourless   Crystal              -1            0
# ...            ...            ...       ...             ...          ...
# 59995  Psychedelic          Black  Granules               0            0
# 59996       Opioid         Purple  Granules               1            0
# 59997      Unknown     Colourless   Crystal              -1            0
# 59998       Opioid          Green    Pebble               1            0
# 59999       Opioid           Grey    Pebble               1            0
#
#       ftir component 0            ftir component 1 ftir component 2  \
# 0             Fentanyl                  Erythritol         Caffeine
# 1      Uncertain match                    Fentanyl              NaN
# 2        Flualprazolam  Microcrystalline cellulose              NaN
# 3             Fentanyl                    Mannitol         Caffeine
# 4      Methamphetamine                         NaN              NaN
# ...                ...                         ...              ...
# 59995  Uncertain match                  Phenacetin              NaN
# 59996         Caffeine                    Inositol       Heroin hcl
# 59997  Methamphetamine                         NaN              NaN
# 59998         Fentanyl                    Caffeine         Mannitol
# 59999         Caffeine                    Fentanyl              NaN
#
#       ftir component 3 ftir component 4 ftir component 5
# 0                  NaN              NaN              NaN
# 1                  NaN              NaN              NaN
# 2                  NaN              NaN              NaN
# 3           Bromazolam              NaN              NaN
# 4                  NaN              NaN              NaN
# ...                ...              ...              ...
# 59995              NaN              NaN              NaN
# 59996         Fentanyl              NaN              NaN
# 59997              NaN              NaN              NaN
# 59998         Mannitol         Caffeine         Fentanyl
# 59999              NaN              NaN              NaN
#
# [60000 rows x 15 columns]

# %%
CFG
# Out:
# CFG(PATH_TO_DRIVER='C:\\\\Users\\\\broug\\\\chromedriver.exe', URL='https://drugcheckingbc.ca/dashboard/', WINDOW_SIZE=(1280, 680), USER_AGENT='Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36', CHROME_OPTS=['--start-maximised', '--headless', '--incognito', 'user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36'], FIRST_IFRAME_WAIT=30, SECOND_IFRAME_WAIT=10, HEROKU_WAIT=10, REACT_WAIT=10, RESULT_BUTTON_WAIT=30, MAX_TRIES=5, WAIT=60, DATA_PATH=None, NUM_WORKERS=3, WAIT_INTERVAL=5, SEC_HEADSTART=60, DATE='2023-02-26', SAVE=True, USE_OLDER_DATA=True)
