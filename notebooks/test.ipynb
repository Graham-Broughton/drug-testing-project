# %%
import pandas as pd
import geopandas as gpd
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 300)

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
# %matplotlib inline

import os
import sys
import datetime
import pickle

import warnings; warnings.filterwarnings('ignore')

sys.path.append('..')
from config import CFG
CFG = CFG()
from src.data.process_data import process_data
date = datetime.datetime(2023, 2, 10).strftime('%Y-%m-%d')
CFG.DATE = date

# %%
df = pd.read_csv(os.path.join(CFG.RAW_DATA_PATH, f"df-{CFG.DATE}.csv"))

# %%
df = process_data(df)

# %%
df.to_csv(os.path.join(CFG.PROCESSED_DATA_PATH, f"df-processed-{CFG.DATE}.csv"), index=False)

# %%
d = pickle.load(open(os.path.join(CFG.RAW_DATA_PATH, f"df-2023-03-01.pkl"), 'rb'))

# %%
d['df']
# Out:
#     VISIT DATE       CITY                   SITE         EXPECTED  DRUG  \
# 0          NaN        NaN                    NaN                    NaN
# 1   2023-01-31  Penticton              Fairhaven  Down (Unknown Opioid)
# 2   2023-01-31  Vancouver  Get Your Drugs Tested                Unknown
# 3   2023-01-31  Vancouver  Get Your Drugs Tested             Alprazolam
# 4   2023-01-31    Nanaimo                   CMHA  Down (Unknown Opioid)
# ..         ...        ...                    ...                    ...
# 16  2018-11-30  Vancouver                 Insite               Fentanyl
# 17  2018-11-30  Vancouver         St. Paul's OPS               Fentanyl
# 18  2018-11-30  Vancouver                 Insite  Down (Unknown Opioid)
# 19  2018-11-30  Vancouver                 Insite               Fentanyl
# 20  2018-11-30  Vancouver                 Insite                   MDMA
#
#        CATEGORY         COLOUR   TEXTURE FENTANYL  STRIP BENZO  STRIP  \
# ...
